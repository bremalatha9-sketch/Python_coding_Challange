# %%
#Day 40 – List Methods and Slicing
#Project Title: Contact Directory
contacts=[
           ["vijay","9994077567","vijay@yahoo.com"],
           ["jay","9994167191","jay@yahoo.com"],
           ["latha","9893234244","prem@gmail.com"]
]
print("The given contacts are : " ,contacts)
name =input('enter the name           :')
phone=input("Enter the contact number:")
email=input("enter the email address  :")
new_contacts=[name,phone,email]
contacts.append([new_contacts])
print("The new contacts are : " ,new_contacts)
print("the new contact list:", contacts)
contacts.pop()
print("after removed contacts  :", contacts)
name=input("enter the name   :")
phone=input("enter the phone number:")
email=input("Enter the email address :")
new_contact=[name,phone,email]
contacts.append(new_contact)
contacts.sort()
print("sorted contact list  :",contacts)
# Out:
# The given contacts are :  [['vijay', '9994077567', 'vijay@yahoo.com'], ['jay', '9994167191', 'jay@yahoo.com'], ['latha', '9893234244', 'prem@gmail.com']]
# enter the name           :ryan
# Enter the contact number:9890976547
# enter the email address  :ryan@gmail.com
# The new contacts are :  ['ryan', '9890976547', 'ryan@gmail.com']
# the new contact list: [['vijay', '9994077567', 'vijay@yahoo.com'], ['jay', '9994167191', 'jay@yahoo.com'], ['latha', '9893234244', 'prem@gmail.com'], [['ryan', '9890976547', 'ryan@gmail.com']]]
# after removed contacts  : [['vijay', '9994077567', 'vijay@yahoo.com'], ['jay', '9994167191', 'jay@yahoo.com'], ['latha', '9893234244', 'prem@gmail.com']]
# enter the name   :aditya
# enter the phone number:965743523
# Enter the email address :aditya.yahoo.com
# sorted contact list  : [['aditya', '965743523', 'aditya.yahoo.com'], ['jay', '9994167191', 'jay@yahoo.com'], ['latha', '9893234244', 'prem@gmail.com'], ['vijay', '9994077567', 'vijay@yahoo.com']]
