# %%
#Student Profile Creator
#1.Store student Details
Student_Name      = 'Aditya'
Student_Age       =  '16'
Subjects          = ['Maths','Science','English']
#2.Display the students informations
print('Name                               :',Student_Name)
print('Age                                :',Student_Age)
print('Favourite Subjects                 :',Subjects)
#3.Updating informations
Subjects.append('Computer Science')
print('Updated student s favourite subject:',Subjects)
# Out:
# Name                              : Aditya
# Age                               : 16
# Favourite Subjects                : ['Maths', 'Science', 'English']
# Updated student s favourite subject: ['Maths', 'Science', 'English', 'Computer Science']
