# %%
total_items = 0
subtotal = 0

while True:
    price = float(input("Enter item price (0 to stop): "))

    if price == 0:
        break

    if price < 0:
        print("Invalid price")
        continue

    total_items = total_items + 1
    subtotal = subtotal + price

# Discount
if subtotal >= 1000:
    discount = subtotal * 20 / 100
elif subtotal >= 500:
    discount = subtotal * 10 / 100
elif subtotal >= 200:
    discount = subtotal * 5 / 100
else:
    discount = 0

final_total = subtotal - discount

# Bill
print("\n--- Bill Summary ---")
print("Total items:", total_items)
print("Subtotal:", subtotal)
print("Discount:", discount)
print("Final total:", final_total)
# Out:
# Enter item price (0 to stop): 879
# Enter item price (0 to stop): 567
# Enter item price (0 to stop): 9000
# Enter item price (0 to stop): -98
# Invalid price
# Enter item price (0 to stop): 900
# Enter item price (0 to stop): 0
#
# --- Bill Summary ---
# Total items: 4
# Subtotal: 11346.0
# Discount: 2269.2
# Final total: 9076.8
