# %%
#analyzing student exam scores to generate performance reports.
scores=[98,70,76,82,77,69,95,79,85,88]
s=[]
Tscore=0
for index,score in enumerate(scores):
    print("Index :" ,index,"Scores :",score)
for score in scores:
  if score>=75:
      s.append(score)

print("Above 75 scores  :", s)
Avg=sum(scores)/len(scores)
print("Average Score    :",Avg)
# Out:
# Index : 0 Scores : 98
# Index : 1 Scores : 70
# Index : 2 Scores : 76
# Index : 3 Scores : 82
# Index : 4 Scores : 77
# Index : 5 Scores : 69
# Index : 6 Scores : 95
# Index : 7 Scores : 79
# Index : 8 Scores : 85
# Index : 9 Scores : 88
# Above 75 scores  : [98, 76, 82, 77, 95, 79, 85, 88]
# Average Score    : 81.9
