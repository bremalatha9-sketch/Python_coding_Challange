# %%
#Day 39 – Tuple, Immutable vs Mutable, List Creation
#Retail Inventory Manager
categories=("Electronics","clothing","stationary")
Products=["laptop","shirt","pencil"]
new_products=input("Enter the new product: ")
Products.append(new_products)
print("The new list of products",Products)
index=int(input("the deleting products: "))
Products.pop(index)

print("the new products  : ",Products)
print("the new catagories: ",categories)
#categories is the tuple it cannot change this is immutable
#products are in list it can change it is mutable
# Out:
# Enter the new product: tab
# The new list of products ['laptop', 'shirt', 'pencil', 'tab']
# the deleting products: 0
# the new products  :  ['shirt', 'pencil', 'tab']
# the new catagories:  ('Electronics', 'clothing', 'stationary')
